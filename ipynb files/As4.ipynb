# %% [markdown]
# MINOR ASSIGNMENT-4: LIST AND TUPLES – SOLUTIONS
# 1. List of size N with random values, sum & average
# import random
#
# N = int(input("Enter size: "))
# lst = [random.randint(1, 100) for _ in range(N)]
# print("List:", lst)
# print("Sum:", sum(lst))
# print("Average:", sum(lst)/N)
#
# 2. Rotate function
# def rotate(a, b, c):
#     return (c, a, b)
#
# a, b, c = "Doug", 22, 1984
#
# for _ in range(3):
#     a, b, c = rotate(a, b, c)
#     print(a, b, c)
#
# 3. Menu-driven list program
# lst = []
#
# while True:
#     print("\n1.Create  2.Display  3.Insert  4.Delete  5.Exit")
#     ch = int(input("Choice: "))
#
#     if ch == 1:
#         n = int(input("Enter N: "))
#         lst = [int(input()) for _ in range(n)]
#
#     elif ch == 2:
#         print(lst)
#
#     elif ch == 3:
#         pos = int(input("Position: "))
#         val = int(input("Value: "))
#         lst.insert(pos, val)
#
#     elif ch == 4:
#         pos = int(input("Position: "))
#         lst.pop(pos)
#
#     elif ch == 5:
#         break
#
# 4. Remove all occurrences
# lst = [1,2,3,2,4,2]
# x = 2
# lst = [i for i in lst if i != x]
# print(lst)
#
# 5. Errors & Outputs
# Code	Result
# a	❌ Error (too many values)
# b	❌ IndexError
# c	❌ TypeError (string immutable)
# d	❌ TypeError
# e	❌ TypeError (tuple immutable)
# f	❌ TypeError
# g	❌ TypeError
# h	❌ NameError
# i	❌ ValueError
# j	❌ TypeError
# k	❌ ValueError
# l	❌ IndexError
# 6. Search element & count
# lst = [int(input()) for _ in range(10)]
# x = int(input("Search: "))
#
# if x in lst:
#     print("Found", lst.count(x), "times")
# else:
#     print("Not found")
#
# 7. Cumulative sum list
# def cumulative(lst):
#     s = 0
#     result = []
#     for i in lst:
#         s += i
#         result.append(s)
#     return result
#
# 8. List of lists (multiples)
# def multiples(n):
#     return [[i*j for j in range(1,6)] for i in range(1,n+1)]
#
# 9. Execution results
#
# 1 ❌ Error
# 2 [1,2,3,1,2,3]
# 3 ❌ TypeError
# 4 3
# 5 List of characters
# 6 ['a',1,'z',26,'d',4,'e',5]
# 7 ['a',1,'z',26,'d',4,['e',5]]
# 8 ['gita','rohan','mohan']
# 9 [2,4,6,8,...,20]
# 10 [2]
# 11 [2,3,4,5,3,4,5,6,...]
# 12 ❌ Error
# 13 ❌ Error
# 14 ❌ Error
# 15 'a, e, i, o, u'
# 16 [('apple','red'),('orange','orange')]
#
# 10. Sum of numeric elements in tuple of tuples
# def sum_tuple(t):
#     return sum(x for inner in t for x in inner if isinstance(x, int))
#
# 11. M×N matrix printing
# m, n = 3, 4
# matrix = [[int(input()) for _ in range(n)] for _ in range(m)]
# for row in matrix:
#     print(*row)
#
# 12. Column sum of 3×4 matrix
# matrix = [[float(x) for x in input().split()] for _ in range(3)]
#
# for col in range(4):
#     print("Sum of column", col, "=", sum(row[col] for row in matrix))
#
# 13. Sort tuple list by second element
# lst = [(1,3),(4,1),(2,2)]
# lst.sort(key=lambda x: x[1])
# print(lst)
#
# 14. Tuple of squares (1–10)
# t = tuple(i*i for i in range(1,11))
# print(t)
#
# 15. 4×4 matrix of 0s and 1s
# import random
#
# mat = [[random.randint(0,1) for _ in range(4)] for _ in range(4)]
# for r in mat:
#     print(*r)
#
# row = max(range(4), key=lambda i: sum(mat[i]))
# col = max(range(4), key=lambda j: sum(mat[i][j] for i in range(4)))
#
# print("Largest row index:", row)
# print("Largest column index:", col)
#
# 16. Check if list is sorted
# lst = list(map(int, input().split()))[1:]
# print("Sorted" if lst == sorted(lst) else "Not sorted")
#
# 17. Mean & standard deviation
# import math
#
# lst = list(map(float, input().split()))
# mean = sum(lst)/len(lst)
# std = math.sqrt(sum((x-mean)**2 for x in lst)/(len(lst)-1))
# print(mean, std)
#
# 18. Square list (comprehension)
# lst = [1,2,3,4]
# print([x*x for x in lst])
#
# 19. Shallow vs Deep copy
# import copy
#
# orig = [['Shallow',2,3],[4,5,6]]
# shallow = orig.copy()
# deep = copy.deepcopy(orig)
#
# shallow[0][0] = 'Changed'
# deep[1][0] = 'Deep'
#
# 20. Cafeteria statistics
# import statistics
#
# ratings = [1,2,5,4,3,5,2,1,3,3,1,4,3,3,3,2,3,3,2,5]
# print("Min:", min(ratings))
# print("Max:", max(ratings))
# print("Mean:", statistics.mean(ratings))
# print("Median:", statistics.median(ratings))
# print("Mode:", statistics.mode(ratings))
# print("Variance:", statistics.variance(ratings))
# print("Std Dev:", statistics.stdev(ratings))
#
# 21. Filter & Map
#
# a) filter → 10 times
# b) map → 5 times
# c) map first → 10 times
#
# 22. Map before filter
# list(filter(lambda x: x % 2 == 0,
#             map(lambda x: x * 2, numbers)))
#
#
# ✔ Map runs on all values first → less efficient
#
# 23. Bar chart
# import matplotlib.pyplot as plt
#
# freq = {i:ratings.count(i) for i in range(1,6)}
# plt.bar(freq.keys(), freq.values())
# plt.show()
#
# 24. Remove tuples of length K
# def remove_k(tuples, k):
#     return [t for t in tuples if len(t) != k]
